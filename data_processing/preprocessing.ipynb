# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## import the libraries

# %%
# !uv add numpy
# Out:
# 96422.12s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Resolved 63 packages in 1ms
# Audited 52 packages in 0.01ms

# %%
import numpy as np #package for scintific calculations
import pandas as pd # dataframes
import matplotlib.pyplot as plt # visualization
import seaborn as sns # better visuals

# %% [markdown]
# ## import the dataset
# # Heade1

# %%
df_=pd.read_csv('data.csv')
df_.shape
# Out:
# (1000, 8)

# %%
df=pd.read_csv('data_with_faults.csv')
df.shape
# Out:
# (1050, 8)

# %%
df.count()
# Out:
# gender                         862
# race_ethnicity                 848
# parental_level_of_education    857
# lunch                          865
# test_preparation_course        855
# math_score                     862
# reading_score                  871
# writing_score                  874
# dtype: int64

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  862.000000     871.000000     874.000000
# mean    66.059165      68.648680      67.770023
# std     16.348199      15.787835      16.151232
# min      0.000000       0.000000       0.000000
# 25%     57.000000      59.000000      57.000000
# 50%     67.000000      70.000000      69.000000
# 75%     77.000000      79.000000      78.000000
# max    100.000000     100.000000     100.000000

# %%
df.tail(5)
# Out:
#       gender race_ethnicity parental_level_of_education         lunch  \
# 1045  female        group B                         NaN      standard
# 1046  female        group A             master's degree  free/reduced
# 1047    male        group D           bachelor's degree  free/reduced
# 1048  female            NaN            some high school           NaN
# 1049     NaN        group E           bachelor's degree      standard
#
#      test_preparation_course  math_score  reading_score  writing_score
# 1045                    none         NaN           63.0           65.0
# 1046                    none        50.0           67.0           73.0
# 1047                     NaN        74.0            NaN           75.0
# 1048                    none        82.0            NaN           80.0
# 1049                    none        82.0            NaN           62.0

# %% [markdown]
# ## Data Exploration

# %%
# delete duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(48)

# %%
df.drop_duplicates(inplace=True)
df.shape
# 4 duplicates removed
# Out:
# (1002, 8)

# %%
df.reset_index(inplace=True)
df.drop('index',axis=1,inplace=True)
df
# Out:
#       gender race_ethnicity parental_level_of_education         lunch  \
# 0     female            NaN                         NaN      standard
# 1        NaN        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4        NaN            NaN                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group D                some college  free/reduced
# 998     male        group D                 high school      standard
# 999      NaN        group C                 high school      standard
# 1000  female            NaN                some college  free/reduced
# 1001  female        group B          associate's degree      standard
#
#      test_preparation_course  math_score  reading_score  writing_score
# 0                        NaN        72.0           72.0            NaN
# 1                        NaN        69.0            NaN           88.0
# 2                        NaN        90.0           95.0           93.0
# 3                       none        47.0            NaN           44.0
# 4                       none        76.0            NaN            NaN
# ...                      ...         ...            ...            ...
# 997                     none        77.0           86.0           86.0
# 998                     none         NaN           73.0           68.0
# 999                     none       100.0           56.0           51.0
# 1000               completed        48.0           56.0           58.0
# 1001                    none         NaN          100.0           78.0
#
# [1002 rows x 8 columns]

# %%
df.head(5)
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female            NaN                         NaN      standard
# 1     NaN        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4     NaN            NaN                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                     NaN        72.0           72.0            NaN
# 1                     NaN        69.0            NaN           88.0
# 2                     NaN        90.0           95.0           93.0
# 3                    none        47.0            NaN           44.0
# 4                    none        76.0            NaN            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       819 non-null    object
#  1   race_ethnicity               811 non-null    object
#  2   parental_level_of_education  819 non-null    object
#  3   lunch                        826 non-null    object
#  4   test_preparation_course      810 non-null    object
#  5   math_score                   822 non-null    float64
#  6   reading_score                834 non-null    float64
#  7   writing_score                837 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 62.8+ KB

# %%
df.isnull().sum()
# Out:
# gender                         188
# race_ethnicity                 202
# parental_level_of_education    193
# lunch                          185
# test_preparation_course        195
# math_score                     188
# reading_score                  179
# writing_score                  176
# dtype: int64

# %%
#Check if there is any null values
df.isna().sum()
# Out:
# gender                         188
# race_ethnicity                 202
# parental_level_of_education    193
# lunch                          185
# test_preparation_course        195
# math_score                     188
# reading_score                  179
# writing_score                  176
# dtype: int64

# %%
import pandas as pd

# Sample dataset
data = pd.read_csv('data_with_faults.csv')
df = pd.DataFrame(data)
print(type(df))

# original data
print("Original Data:")
print(df)

# Remove duplicates
df = df.drop_duplicates()

# Handle missing values
df['math_score'] = df['math_score'].fillna(df['math_score'].mean())  # Replace with mean math_score
df['writing_score'] = df['writing_score'].fillna(df['writing_score'].median())  # Replace with median writing_score
df['parental_level_of_education'] = df['parental_level_of_education'].fillna('some college')  # Replace None with 'No Activity'

# cleaned data
print("\nCleaned Data:")
print(df)

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
#Unique value in each columns

# %%
unique=df.nunique()
unique
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     82
# reading_score                  75
# writing_score                  78
# dtype: int64

# %%
df['Company'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mlops-course/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Company'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df['Company'].unique()
#
# File ~/mlops-course/.venv/lib/python3.10/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/mlops-course/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Company'

# %%
# observations: here 'Infosys' & 'Infosys Pvt Lmt','TCS' & 'Tata Consultancy Services','CTS' & 'Congnizant'('Cognizant') 
# are same.
# Treat them appropriately.

# %%
df.describe()
# Out:
#               Age       Salary      Gender
# count  127.000000   121.000000  144.000000
# mean    30.527559  5283.471074    0.222222
# std     11.114717  2585.373600    0.417191
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     33.000000  5000.000000    0.000000
# 75%     37.500000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %% [markdown]
# ## Data Cleaning

# %%
#Outlier detection
#using IQR
#Chances of getting outliers are only in the 'Age' and 'Salary' columns.

# %% [markdown]
# *************************************************************************************************************************

# %% [markdown]
# *************************************************************************************************************************
